# %% [markdown]
# ### Boolean Values
# -  Boolean data type has only two values: True and False.
#
# ### Comparison Operators
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# - Note :  an integer or floating-point value will always be unequal to a string value.

# %% [markdown]
# ### Boolean Operators
# - and
# ![image.png](attachment:image.png)
# - or
# ![image-2.png](attachment:image-2.png)
# - not
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Mixing Boolean and Comparison Operators
# ![image.png](attachment:image.png)
#
# #### Elements of Flow Control
#
# 1. Conditions - Conditions always evaluate down to a Boolean value, True or False
#  - A flow control statement decides what to do based on whether its condition is True or False, and almost every flow control statement uses a condition
#
# 2.  Block of code - There are  three rules for blocks.
#
# - Blocks begin when the indentation increases.
#
#  - Blocks can contain other blocks.
#
#  - Blocks end when the indentation decreases to zero or to a containing  block’s indentation.

# %% [markdown]
# ### Flow Control Statements
# - if Statements
# - else Statements
# - elif Statements

# %% [markdown]
# loops- :
#
#     - while loop
#
#     - for Loops and the range() Function   and The Starting, Stopping, and Stepping Arguments to range()

# %%
name = ''
while name != 'your name':
  print('Please type your name.')
  name = input()
print('Thank you!')
# Out:
# Please type your name.
#
# Please type your name.
#
# Please type your name.
# prikshit
# Please type your name.
# s
# Please type your name.
#
# Please type your name.
#
# Please type your name.
# your name
# Thank you!

# %%
print('My name is')
for i in range(5):
     print('Jimmy Five Times (' + str(i) + ')')
# Out:
# My name is
# Jimmy Five Times (0)
# Jimmy Five Times (1)
# Jimmy Five Times (2)
# Jimmy Five Times (3)
# Jimmy Five Times (4)

# %% [markdown]
# - **break Statements** - If the execution reaches a break statement, it immediately exits the while loop’s clause
# - **Continue Statements** - When the program execution reaches a continue statement, the program execution immediately jumps back to the start of the loop and reevaluates the loop’s condition

# %% [markdown]
# -  Importing Modules - Once you import a module, you can use all the cool functions of that  module
