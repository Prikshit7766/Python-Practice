# %%
conda env list
# Out:
# # conda environments:
# #
#                          C:\Users\HP\Anaconda3
# base                  *  C:\Users\HP\anaconda3
# Mongodb                  C:\Users\HP\anaconda3\envs\Mongodb
# Mysql_                   C:\Users\HP\anaconda3\envs\Mysql_
# all                      C:\Users\HP\anaconda3\envs\all
# task7                    C:\Users\HP\anaconda3\envs\task7
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
#best library

# %%
# what ever we have dicussed in sql can be done using pandas ...

# %%
# reading the dataset 
#reading excel sheet
df=pd.read_excel(r"D:\full_stack\material\July24\data fsds\Attribute DataSet.xlsx")
# when you are reading a data , it by default try to give data frame

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.to_csv("Attribute DataSet.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# pandas.core.frame.DataFrame --- meaning tabular

# %%
# operations
#1. handling null values --(Nan)
#2. normal distribution
#3. analytics

# %%
# in excel there is a possibility data is avilable in differet excel sheet
# by default system try to read data from the first data
# but there is a chance of 100 sheets
# how to read data from different sheet  (1 excel file can have muliple sheets)

# %%
df=pd.read_excel(r"D:\full_stack\material\July24\data fsds\Attribute DataSet.xlsx",sheet_name="Sheet2")

# %%
df
# Out:
#      Dress_ID     Style    Price  Rating  Size
# 0  1006032852      Sexy      Low     4.6     M
# 1  1212192089    Casual      Low     0.0     L
# 2  1190380701   vintage     High     0.0     L
# 3   966005983     Brief  Average     4.6     L
# 4   876339541      cute      Low     4.5     M
# 5  1068332458  bohemian      Low     0.0     M
# 6  1220707172    Casual  Average     0.0    XL
# 7  1219677488   Novelty  Average     0.0  free
# 8  1113094204     Flare  Average     0.0  free

# %%
# what ever data set we ave in first place it is trying to treat that as the colunm header
#by default
# how to avoid it

# %%
df=pd.read_excel(r"D:\full_stack\material\July24\data fsds\Attribute DataSet.xlsx",sheet_name="Sheet2",header=None)

# %%
df
# Out:
#             0         1        2       3     4
# 0    Dress_ID     Style    Price  Rating  Size
# 1  1006032852      Sexy      Low     4.6     M
# 2  1212192089    Casual      Low       0     L
# 3  1190380701   vintage     High       0     L
# 4   966005983     Brief  Average     4.6     L
# 5   876339541      cute      Low     4.5     M
# 6  1068332458  bohemian      Low       0     M
# 7  1220707172    Casual  Average       0    XL
# 8  1219677488   Novelty  Average       0  free
# 9  1113094204     Flare  Average       0  free

# %%
df=pd.read_excel(r"D:\full_stack\material\July24\data fsds\Attribute DataSet.xlsx",sheet_name="Sheet2")

# %%
df
# Out:
#      Dress_ID     Style    Price  Rating  Size
# 0  1006032852      Sexy      Low     4.6     M
# 1  1212192089    Casual      Low     0.0     L
# 2  1190380701   vintage     High     0.0     L
# 3   966005983     Brief  Average     4.6     L
# 4   876339541      cute      Low     4.5     M
# 5  1068332458  bohemian      Low     0.0     M
# 6  1220707172    Casual  Average     0.0    XL
# 7  1219677488   Novelty  Average     0.0  free
# 8  1113094204     Flare  Average     0.0  free

# %%
# to give my own colunm name

# %%
df=pd.read_excel(r"D:\full_stack\material\July24\data fsds\Attribute DataSet.xlsx",header=None,sheet_name="Sheet2",names=["a","b","c","d","e"])

# %%
df
# Out:
#             a         b        c       d     e
# 0    Dress_ID     Style    Price  Rating  Size
# 1  1006032852      Sexy      Low     4.6     M
# 2  1212192089    Casual      Low       0     L
# 3  1190380701   vintage     High       0     L
# 4   966005983     Brief  Average     4.6     L
# 5   876339541      cute      Low     4.5     M
# 6  1068332458  bohemian      Low       0     M
# 7  1220707172    Casual  Average       0    XL
# 8  1219677488   Novelty  Average       0  free
# 9  1113094204     Flare  Average       0  free

# %%
df.head(2)
# Out:
#             a      b      c       d     e
# 0    Dress_ID  Style  Price  Rating  Size
# 1  1006032852   Sexy    Low     4.6     M

# %%
df.tail()
# Out:
#             a         b        c    d     e
# 5   876339541      cute      Low  4.5     M
# 6  1068332458  bohemian      Low    0     M
# 7  1220707172    Casual  Average    0    XL
# 8  1219677488   Novelty  Average    0  free
# 9  1113094204     Flare  Average    0  free

# %%
#csv formal---> coma seprated format
# reading csv file
data =pd.read_csv(r"D:\full_stack\material\July24\data fsds\haberman.csv")

# %%
data
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
data.head()
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
data.tail()
# Out:
#      30  64  1  1.1
# 300  75  62  1    1
# 301  76  67  0    1
# 302  77  65  3    1
# 303  78  65  1    2
# 304  83  58  2    2

# %%
data =pd.read_csv(r"D:\full_stack\material\July24\data fsds\haberman.csv",header=None)

# %%
data
# Out:
#       0   1  2  3
# 0    30  64  1  1
# 1    30  62  3  1
# 2    30  65  0  1
# 3    31  59  2  1
# 4    31  65  4  1
# ..   ..  .. .. ..
# 301  75  62  1  1
# 302  76  67  0  1
# 303  77  65  3  1
# 304  78  65  1  2
# 305  83  58  2  2
#
# [306 rows x 4 columns]

# %%
# see the corresponding txt file ----> give the name

data =pd.read_csv(r"D:\full_stack\material\July24\data fsds\haberman.csv",header=None,names=["Age","year"," Number of positive axillary nodes detected","Survival status"])

# %%
data
# Out:
#      Age  year   Number of positive axillary nodes detected  Survival status
# 0     30    64                                            1                1
# 1     30    62                                            3                1
# 2     30    65                                            0                1
# 3     31    59                                            2                1
# 4     31    65                                            4                1
# ..   ...   ...                                          ...              ...
# 301   75    62                                            1                1
# 302   76    67                                            0                1
# 303   77    65                                            3                1
# 304   78    65                                            1                2
# 305   83    58                                            2                2
#
# [306 rows x 4 columns]

# %%
# now we have to created a copy of csv file 
# replace the coma with #

# %%
# now we have to read

# %%
data =pd.read_csv(r"D:\full_stack\material\July24\data fsds\haberman - Copy.csv",header=None,names=["Age","year"," Number of positive axillary nodes detected","Survival status"])

# %%
data
# Out:
#            Age  year   Number of positive axillary nodes detected  \
# 0    30#64#1#1   NaN                                          NaN
# 1    30#62#3#1   NaN                                          NaN
# 2    30#65#0#1   NaN                                          NaN
# 3    31#59#2#1   NaN                                          NaN
# 4    31#65#4#1   NaN                                          NaN
# ..         ...   ...                                          ...
# 301  75#62#1#1   NaN                                          NaN
# 302  76#67#0#1   NaN                                          NaN
# 303  77#65#3#1   NaN                                          NaN
# 304  78#65#1#2   NaN                                          NaN
# 305  83#58#2#2   NaN                                          NaN
#
#      Survival status
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# ...

# %%
data =pd.read_csv(r"D:\full_stack\material\July24\data fsds\haberman - Copy.csv",header=None,names=["Age","year"," Number of positive axillary nodes detected","Survival status"],sep="#")

# %%
data
# Out:
#      Age  year   Number of positive axillary nodes detected  Survival status
# 0     30    64                                            1                1
# 1     30    62                                            3                1
# 2     30    65                                            0                1
# 3     31    59                                            2                1
# 4     31    65                                            4                1
# ..   ...   ...                                          ...              ...
# 301   75    62                                            1                1
# 302   76    67                                            0                1
# 303   77    65                                            3                1
# 304   78    65                                            1                2
# 305   83    58                                            2                2
#
# [306 rows x 4 columns]

# %%
# reading data from git hub
#directly

# %%
data1=pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv")

# %%
data1
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
#saving data

# %%
data2=pd.read_csv("https://raw.githubusercontent.com/sudh9931/data/main/haberman.csv",header=None)

# %%
data2

# %%
# reading data from 2014-15 NBA Player Stats: Totals
# https://www.basketball-reference.com/leagues/NBA_2015_totals.html

# %%
# if we have to read this data set

# %%
a=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
a
# reading without doing scraping 
# it is reading  all the tabluar info
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
#we can scrap all the things --> diccus later

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 1

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(a[0])
# Out:
# pandas.core.frame.DataFrame

# %%
# reading json data
# we have to create structure of it
# how to do it

# %%
#json ---> combination of multiple dict

# %%
js=pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
js.head(2)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           html_url          id  \
# 0  https://github.com/pandas-dev/pandas/pull/48234  1349964738
# ...

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
js["user"][0]
# Out:
# {'login': 'phofl',
#  'id': 61934744,
#  'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/phofl',
#  'html_url': 'https://github.com/phofl',
#  'followers_url': 'https://api.github.com/users/phofl/followers',
#  'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#  'organizations_url': 'https://api.github.com/users/phofl/orgs',
#  'repos_url': 'https://api.github.com/users/phofl/repos',
#  'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/phofl/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
# coverting  excel data into jason
# like i have to dump this data into mogodb

df=pd.read_excel(r"D:\full_stack\material\July24\data fsds\Attribute DataSet.xlsx")

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
# so how to do it
#json consider the table column name sa key and row as values

# %%
df.to_json("testJason.json")

# %%
pwd
# Out:
# 'D:\\full_stack\\MyPractice\\Python'

# %%
# reading data from mysql server we can also do do that

# %%
# storing a data frame

# %%
df.to_csv("pandas_day1.csv",sep="#",index=False)
