# %%
# How to create a class:
class Item:
    def calculate_total_price():
        pass

# How to create an instance of a class
item1 = Item()

# Assign attributes:
item1.name = "Phone"
item1.price = 100
item1.quantity = 5

# %%
item1.calculate_total_price()

# so the problem is that when we call method from a class it so one parameter is auto generated that python wants use to recive intentionally 
# python passes the object itself as first argument  whenwe go ahead and call those methods

# in python we are not allowed to create methods that do  not take argumnets
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\full_stack\MyPractice\Python\learning from youtube\PythonOOP\1.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/full_stack/MyPractice/Python/learning%20from%20youtube/PythonOOP/1.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> item1.calculate_total_price()
#       <a href='vscode-notebook-cell:/d%3A/full_stack/MyPractice/Python/learning%20from%20youtube/PythonOOP/1.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> # so the problem is that when we call method from a class it so one parameter is auto generated that python wants use to recive intentionally
#       <a href='vscode-notebook-cell:/d%3A/full_stack/MyPractice/Python/learning%20from%20youtube/PythonOOP/1.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> # python passes the object itself as first argument  whenwe go ahead and call those methods
# ...

# %%
# How to create a class:
class Item:
    def calculate_total_price(self):
        pass

# How to create an instance of a class
item1 = Item()

# Assign attributes:
item1.name = "Phone"
item1.price = 100
item1.quantity = 5

item1.calculate_total_price()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# How to create a class:
class Item:
    def calculate_total_price(self, x, y):
        return x * y

# How to create an instance of a class
item1 = Item()

# Assign attributes:
item1.name = "Phone"
item1.price = 100
item1.quantity = 5

# Calling methods from instances of a class:
print(item1.calculate_total_price(item1.price, item1.quantity))

# How to create an instance of a class (We could create as much as instances we'd like to)
item2 = Item()

# Assign attributes
item2.name = "Laptop"
item2.price = 1000
item2.quantity = 3

# Calling methods from instances of a class: 
print(item2.calculate_total_price(item2.price, item2.quantity))
# Out:
# 500
# 3000

# %% [markdown]
# ###  Constructor & __init

# %%
class Item:
    def __init__(self):   # magic method
        print("i am created")




item1 = Item()   # when we have declared this instance of the class then this trigger the actions that we have defined in __ini__ method
# Out:
# i am created

# %%
class Items:
    def __init__(self, name):   # magic method
        self.name = name
        print(f"instance  created for {self.name}")

        




item1 = Items(name="phone")
# Out:
# instance  created for phone

# %%
item1.name
# Out:
# 'phone'

# %%
class Item:
    def __init__(self, name,price,quantity):   # magic method
        self.name = name
        self.price =price
        self.quantity = quantity
        print(f"instance  created for {self.name}")

    def calcilate_total_price(self):
        pass
        




item1 = Item(name="phone",price =10, quantity=2 )


print(item1.price)
print(item1.name)

item2 = Item(name="laptop",price =10, quantity=2 )


print(item2.price)
print(item2.name)
# Out:
# instance  created for phone
# 10
# phone
# instance  created for laptop
# 10
# laptop

# %%
# suppose we check does that laptop have numpad or not so this is not a realistic attribute that we want to assign for phone  so waht we do 

class Item:
    def __init__(self, name,price,quantity):   # magic method
        self.name = name
        self.price =price
        self.quantity = quantity
        print(f"instance  created for {self.name}")

    def calcilate_total_price(self):
        pass
        




item1 = Item(name="phone",price =10, quantity=2 )

item2 = Item(name="laptop",price =10, quantity=2 )

item2.has_numpad= True   # so here we  doing attribute assignment after instacate the class (it is possible)

# %%
class Item:
    def __init__(self, name,price,quantity):   # magic method
        self.name = name
        self.price =price
        self.quantity = quantity
        print(f"instance  created for {self.name}")

    def calcilate_total_price(self):
        return self.price * self.quantity
        




item1 = Item(name="phone",price =10, quantity=2 )

item2 = Item(name="laptop",price =10, quantity=2 )

print(item2.calcilate_total_price())
# Out:
# instance  created for phone
# instance  created for laptop
# 20

# %%
## what will happen if we pass wong type of data 

class Item:
    def __init__(self, name,price,quantity):   # magic method
        self.name = name
        self.price =price
        self.quantity = quantity
        print(f"instance  created for {self.name}")

    def calcilate_total_price(self):
        return self.price * self.quantity
        




item1 = Item(name="phone",price =10, quantity="2" )

item2 = Item(name="laptop",price ="10", quantity=4 )

print(item1.calcilate_total_price())
print(item2.calcilate_total_price())

# item1  : so it is printing the string 10 times
# Out:
# instance  created for phone
# instance  created for laptop
# 2222222222
# 10101010

# %%
# using Typing to maintain the datatype

class Item:
    def __init__(self, name:str,price:float,quantity:int):   # magic method
        self.name = name
        self.price =price
        self.quantity = quantity
        print(f"instance  created for {self.name}")

    def calcilate_total_price(self):
        return self.price * self.quantity
        




item1 = Item(name="phone",price =10, quantity=2 )

item2 = Item(name="laptop",price =10, quantity=4 )

print(item1.calcilate_total_price())
print(item2.calcilate_total_price())
# Out:
# instance  created for phone
# instance  created for laptop
# 20
# 40

# %% [markdown]
# we will get this type of message
#
# ![image.png](attachment:image.png)

# %%
# suppose you never wanted to recive negative price and qunatity so for that we have to do validation of the data that user is inserting


class Item:
    def __init__(self, name:str,price:float,quantity:int): 
        # run validation 
        assert price >=0,f"price `{price}` is not grater than zero!"
        assert quantity >=0 ,f"quantity `{quantity}` is not grater than zero!"
        #assign to self object 
        self.name = name
        self.price =price
        self.quantity = quantity
        print(f"instance  created for {self.name}")

    def calcilate_total_price(self):
        return self.price * self.quantity
        




item1 = Item(name="phone",price =-110, quantity=2 )

item2 = Item(name="laptop",price =10, quantity=4 )

print(item1.calcilate_total_price())
print(item2.calcilate_total_price())
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# d:\full_stack\MyPractice\Python\learning from youtube\PythonOOP\1.ipynb Cell 16 line 2
#      <a href='vscode-notebook-cell:/d%3A/full_stack/MyPractice/Python/learning%20from%20youtube/PythonOOP/1.ipynb#X31sZmlsZQ%3D%3D?line=14'>15</a>     def calcilate_total_price(self):
#      <a href='vscode-notebook-cell:/d%3A/full_stack/MyPractice/Python/learning%20from%20youtube/PythonOOP/1.ipynb#X31sZmlsZQ%3D%3D?line=15'>16</a>         return self.price * self.quantity
# ---> <a href='vscode-notebook-cell:/d%3A/full_stack/MyPractice/Python/learning%20from%20youtube/PythonOOP/1.ipynb#X31sZmlsZQ%3D%3D?line=21'>22</a> item1 = Item(name="phone",price =-110, quantity=2 )
# ...

# %%
# consider you want to make use of an attribute that will gloabl by creating a candidate that will be shared among all the instances 
# that if we want apply sale on the shhop and apply discount on all items 
# so we can crate such attributes and it is reffered as class attributes
# this class attribute can we acessed via instance level and class level
class Item:
    pay_rate = 0.8   # the pay rate after 20% discount
    def __init__(self, name:str,price:float,quantity:int): 
        # run validation 
        assert price >=0,f"price `{price}` is not grater than zero!"
        assert quantity >=0 ,f"quantity `{quantity}` is not grater than zero!"
        #assign to self object 
        self.name = name
        self.price =price
        self.quantity = quantity
        print(f"instance  created for {self.name}")

    def calcilate_total_price(self):
        return self.price * self.quantity

    
    def apply_discount(self,):
        pass





item1 = Item(name="phone",price =110, quantity=2 )
item2 = Item(name="laptop",price =10, quantity=4 )
print(Item.pay_rate)    #class level
print(item1.pay_rate)   #instance level   : so when we have instance  our hand , so first it check the instance level attributes and if the attributes is not there then it tries to bring that attribute from class level
print(item2.pay_rate)   #instance level      ``
# Out:
# instance  created for phone
# instance  created for laptop
# 0.8
# 0.8
# 0.8

# %%
class Item:
    pay_rate = 0.8   # the pay rate after 20% discount
    def __init__(self, name:str,price:float,quantity:int): 
        # run validation 
        assert price >=0,f"price `{price}` is not grater than zero!"
        assert quantity >=0 ,f"quantity `{quantity}` is not grater than zero!"
        #assign to self object 
        self.name = name
        self.price =price
        self.quantity = quantity
        print(f"instance  created for {self.name}")

    def calcilate_total_price(self):
        return self.price * self.quantity

    
    def apply_discount(self,):
        pass





item1 = Item(name="phone",price =110, quantity=2 )
item2 = Item(name="laptop",price =10, quantity=4 )



# another build in magic method
# .__dict__  it will return  all the attributes that we have in this object with which we apply this method
print(Item.__dict__)   # return the attrubutes for class level
print(item1.__dict__) # return the attrubutes for instance level
# Out:
# instance  created for phone
# instance  created for laptop
# {'__module__': '__main__', 'discount': 0.8, '__init__': <function Item.__init__ at 0x00000223B7F62980>, 'calcilate_total_price': <function Item.calcilate_total_price at 0x00000223B7F61260>, 'apply_discount': <function Item.apply_discount at 0x00000223B7F616C0>, '__dict__': <attribute '__dict__' of 'Item' objects>, '__weakref__': <attribute '__weakref__' of 'Item' objects>, '__doc__': None}
# {'name': 'phone', 'price': 110, 'quantity': 2}

# %%
class Item:
    pay_rate = 0.8   # the pay rate after 20% discount
    def __init__(self, name:str,price:float,quantity:int): 
        # run validation 
        assert price >=0,f"price `{price}` is not grater than zero!"
        assert quantity >=0 ,f"quantity `{quantity}` is not grater than zero!"
        #assign to self object 
        self.name = name
        self.price =price
        self.quantity = quantity
        print(f"instance  created for {self.name}")

    def calcilate_total_price(self):
        return self.price * self.quantity

    
    def apply_discount(self,):
        self.price =self.price * Item.pay_rate 
        return self.price   




item1 = Item(name="phone",price =110, quantity=2 )
item2 = Item(name="laptop",price =10, quantity=4 )
print(item1.apply_discount())
print(item2.apply_discount())
# Out:
# instance  created for phone
# instance  created for laptop
# 88.0
# 8.0

# %%
# but if we want to apply  different discount for some specific itme for that we need do somthing!!

class Item:
    pay_rate = 0.8   # the pay rate after 20% discount
    def __init__(self, name:str,price:float,quantity:int): 
        # run validation 
        assert price >=0,f"price `{price}` is not grater than zero!"
        assert quantity >=0 ,f"quantity `{quantity}` is not grater than zero!"
        #assign to self object 
        self.name = name
        self.price =price
        self.quantity = quantity
        print(f"instance  created for {self.name}")

    def calcilate_total_price(self):
        return self.price * self.quantity

    
    def apply_discount(self,):
        self.price =self.price * self.pay_rate     # Item.pay_rate this will not work becuse we are acess the classs level attribute and there we have defined the play_rate as 0.8 so we need to wrte like self.play_rate 
        return self.price   




item1 = Item(name="phone",price =110, quantity=2 )
item2 = Item(name="laptop",price =10, quantity=4 )
item2.pay_rate=0.7  # this will chnage the discount for item 2  
print(item1.apply_discount())
print(item2.apply_discount())
# Out:
# instance  created for phone
# instance  created for laptop
# 88.0
# 7.0

# %%
# consider you are having bigger shop with more items then  track all the items


class Item:
    pay_rate = 0.8  
    all = []
    def __init__(self, name:str,price:float,quantity:int): 
        # run validation 
        assert price >=0,f"price `{price}` is not grater than zero!"
        assert quantity >=0 ,f"quantity `{quantity}` is not grater than zero!"
        #assign to self object 
        self.name = name
        self.price =price
        self.quantity = quantity
        
        # Action to exectue
        Item.all.append(self)  # we are append the self object as we know that self that is reffer to the instnace of an object 

    def calcilate_total_price(self):
        return self.price * self.quantity

    
    def apply_discount(self,):
        self.price =self.price * self.pay_rate     
        return self.price   


item1 = Item("Phone", 100, 1)
item2 = Item("Laptop", 1000, 3)
item3 = Item("Cable", 10, 5)
item4 = Item("Mouse", 50, 5)
item5 = Item("Keyboard", 75, 5)



print(Item.all)
# Out:
# [<__main__.Item object at 0x00000223B8029610>, <__main__.Item object at 0x00000223B7F99410>, <__main__.Item object at 0x00000223B8016110>, <__main__.Item object at 0x00000223B7F76BD0>, <__main__.Item object at 0x00000223B803B310>]

# %%
# so o get the name of all the instance 

for instance in Item.all:
    print(instance.name)
# Out:
# Phone
# Laptop
# Cable
# Mouse
# Keyboard

# %%
print(Item.all)
# Out:
# [<__main__.Item object at 0x00000223B8029610>, <__main__.Item object at 0x00000223B7F99410>, <__main__.Item object at 0x00000223B8016110>, <__main__.Item object at 0x00000223B7F76BD0>, <__main__.Item object at 0x00000223B803B310>]

# %%
# as you see  the object which are stored in the list are not saved in user frendly apporch  so to fix this

class Item:
    pay_rate = 0.8  
    all = []
    def __init__(self, name:str,price:float,quantity:int): 
        # run validation 
        assert price >=0,f"price `{price}` is not grater than zero!"
        assert quantity >=0 ,f"quantity `{quantity}` is not grater than zero!"
        #assign to self object 
        self.name = name
        self.price =price
        self.quantity = quantity
        
        # Action to exectue
        Item.all.append(self)  

    def calcilate_total_price(self):
        return self.price * self.quantity

    
    def apply_discount(self,):
        self.price =self.price * self.pay_rate     
        return self.price   

    def __repr__(self) -> str:
        return f"Item_({self.name!r},{self.price!r},{self.quantity!r})"

item1 = Item("Phone", 100, 1)
item2 = Item("Laptop", 1000, 3)
item3 = Item("Cable", 10, 5)
item4 = Item("Mouse", 50, 5)
item5 = Item("Keyboard", 75, 5)



print(Item.all) # now it is good
# Out:
# [Item_('Phone',100,1), Item_('Laptop',1000,3), Item_('Cable',10,5), Item_('Mouse',50,5), Item_('Keyboard',75,5)]
